# %%
# Just take all width for viz
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import findspark
findspark.init()

import pyspark
from pyspark.sql import SparkSession
import pyspark.sql.functions as F
from pyspark.sql.types import *

import os
import sys

os.environ['PYSPARK_PYTHON'] = sys.executable
os.environ['PYSPARK_DRIVER_PYTHON'] = sys.executable

# %%
spark = SparkSession \
    .builder \
    .master('local[*]') \
    .appName("steam-analysis-eda") \
    .getOrCreate()

# %%
# %%bash
#
# tree ../data -L 2
# Out:
# ../data
# ├── extracts
# │   ├── steam-dataset-distinct-names
# │   ├── steam-dataset_games_28-12
# │   ├── steam-dataset_games_28-12_2
# │   └── steam-dataset_games_28-12_3
# ├── steam-dataset
# │   ├── steam_analysis.Achievements_Percentages
# │   ├── steam_analysis.App_ID_Info
# │   ├── steam_analysis.App_ID_Info_Old
# │   ├── steam_analysis.Friends
# │   ├── steam_analysis.Games_1
# │   ├── steam_analysis.Games_2
# │   ├── steam_analysis.Games_Daily
# │   ├── steam_analysis.Games_Developers
# │   ├── steam_analysis.Games_Developers_Old
# │   ├── steam_analysis.Games_Genres
# │   ├── steam_analysis.Games_Genres_Old
# │   ├── steam_analysis.Games_Publishers
# │   ├── steam_analysis.Games_Publishers_Old
# │   ├── steam_analysis.Groups
# │   └── steam_analysis.Player_Summaries
# ├── steam-review
# │   └── steam-review.csv
# ├── steam-store-games
# │   ├── steam.csv
# │   ├── steam_description_data.csv
# │   ├── steam_media_data.csv
# │   ├── steam_requirements_data.csv
# ...

# %% [markdown]
# #### Steam Dataset Schemas

# %%
dataset_path = "/home/neadex/steam-analysis/data/steam-dataset/"

for filename in os.listdir(dataset_path):
    print('Filename :', filename)
    df = spark.read.parquet("file://" + dataset_path + filename, header=True)
    df.printSchema()
# Out:
# Filename : steam_analysis.Games_Publishers
# root
#  |-- appid: string (nullable = true)
#  |-- Publisher: string (nullable = true)
#
# Filename : steam_analysis.Games_Genres_Old
# root
#  |-- appid: string (nullable = true)
#  |-- Genre: string (nullable = true)
#
# Filename : steam_analysis.Achievements_Percentages
# root
#  |-- Appid: string (nullable = true)
#  |-- Name: string (nullable = true)
#  |-- Percentage: string (nullable = true)
#
# Filename : steam_analysis.Games_2
# root
#  |-- steamid: decimal(20,0) (nullable = true)
#  |-- appid: long (nullable = true)
#  |-- playtime_2weeks: long (nullable = true)
#  |-- playtime_forever: long (nullable = true)
#  |-- dateretrieved: timestamp (nullable = true)
#
# Filename : steam_analysis.Groups
# root
#  |-- steamid: decimal(20,0) (nullable = true)
#  |-- groupid: decimal(20,0) (nullable = true)
#  |-- dateretrieved: timestamp (nullable = true)
#
# Filename : steam_analysis.Player_Summaries
# root
# ...

# %% [markdown]
# #### Steam Review Schema

# %%
dataset_path = "/home/neadex/steam-analysis/data/steam-review/"

for filename in os.listdir(dataset_path):
    print('Filename :', filename)
    df = spark.read.csv("file://" + dataset_path + filename, header=True)
    df.printSchema()
    
df.show()
# Out:
# Filename : steam-review.csv
# root
#
# ++
# ||
# ++
# ++

# %% [markdown]
# #### Steam Store Games Schemas

# %%
dataset_path = "/home/neadex/steam-analysis/data/steam-store-games/"

for filename in os.listdir(dataset_path):
    print('Filename :', filename)
    df = spark.read.csv("file://" + dataset_path + filename, header=True)
    df.printSchema()
# Out:
# Filename : steam_requirements_data.csv
# root
#  |-- steam_appid: string (nullable = true)
#  |-- pc_requirements: string (nullable = true)
#  |-- mac_requirements: string (nullable = true)
#  |-- linux_requirements: string (nullable = true)
#  |-- minimum: string (nullable = true)
#  |-- recommended: string (nullable = true)
#
# Filename : steam_description_data.csv
# root
#  |-- steam_appid: string (nullable = true)
#  |-- detailed_description: string (nullable = true)
#  |-- about_the_game: string (nullable = true)
#  |-- short_description: string (nullable = true)
#
# Filename : steam_media_data.csv
# root
#  |-- steam_appid: string (nullable = true)
#  |-- header_image: string (nullable = true)
#  |-- screenshots: string (nullable = true)
#  |-- background: string (nullable = true)
#  |-- movies: string (nullable = true)
#
# Filename : steamspy_tag_data.csv
# root
#  |-- appid: string (nullable = true)
#  |-- 1980s: string (nullable = true)
# ...

# %% [markdown]
# #### Video Games Sales Schema

# %%
dataset_path = "/home/neadex/steam-analysis/data/video-games-sales/"

for filename in os.listdir(dataset_path):
    print('Filename :', filename)
    df = spark.read.csv("file://" + dataset_path + filename, header=True)
    df.printSchema()
# Out:
# Filename : vgsales.csv
# root
#  |-- Rank: string (nullable = true)
#  |-- Name: string (nullable = true)
#  |-- Platform: string (nullable = true)
#  |-- Year: string (nullable = true)
#  |-- Genre: string (nullable = true)
#  |-- Publisher: string (nullable = true)
#  |-- NA_Sales: string (nullable = true)
#  |-- EU_Sales: string (nullable = true)
#  |-- JP_Sales: string (nullable = true)
#  |-- Other_Sales: string (nullable = true)
#  |-- Global_Sales: string (nullable = true)

# %%
dataset_path = "file:///home/neadex/steam-analysis/data/steam-store-games/steam_description_data.csv"

df = spark.read.csv(games_dataset_path, header=True)
df.printSchema()
# Out:
# root
#  |-- steam_appid: string (nullable = true)
#  |-- detailed_description: string (nullable = true)
#  |-- about_the_game: string (nullable = true)
#  |-- short_description: string (nullable = true)
